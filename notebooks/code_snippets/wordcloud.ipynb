# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt

# text = 'Eixo: Atenção à Saúde Módulo: Bases Moleculares e Celulares (BMC) - 240 horas Conteúdos: Biologia Molecular e Celular (1º) / Histologia (1º) / Embriologia (1º) / Microbiologia e Imunologia (2º) Eixo: Atenção à Saúde Módulo: Bases Morfofuncionais (BMF) - 420h Conteúdos: Anatomia Humana I e II (1º e 2º) / Fisiologia Humana I e II (1º e 2º) / Genética e Bioquímica I (3º) / Bioquímica II (4º) Eixo: Atenção à Saúde Módulo: Bases Fisiopatológicas e Epidemiológicas do Processo Saúde Doença (BFF) - 360h Conteúdos: Patologia Humana I e II (3º e 4º) / Bioestatística (3º) / Epidemiologia I e II (3º e 4º) / Farmacologia I e II (4º e 5º)  Eixo: Educação em Saúde Módulo: Humanidades Médicas (HUMA) – 270h Conteúdos: Filosofia e Sociologia (1º) / Antropologia (2º) / Metodologia aplicada à Saúde (3º) / Ética e Bioética Aplicada (4º) Eixos: Atenção à Saúde, Gestão dos Sistemas de Saúde Clínicas Integradas e Especializadas (CIES) - 720 horas Conteúdos: Clínicas Médicas / Clínicas Cirúrgicas / Saúde Materno-Infantil / Saúde do Idoso / Urgências (do 5º ao 8º período)  Eixo: Gestão dos Sistemas de Saúde Módulo: Saúde Coletiva e Medicina de Família e Comunidade (SCO) – 720h Conteúdos: SUS e políticas de saúde no Brasil (1º)/ APS na rede de atenção à saúde (2º)/ Medicina de Família e Comunidade I (3º)/ Assistência farmacêutica (4º)/ Educação em saúde (5º)/ Vigilância e saúde ambiental (6º)/ Medicina de Família e Comunidade II (7º)/ Racionalidades e saberes não biomédicos das populações amazônicas (8º). Eixo: Atenção à Saúde Módulo: Habilidades Clínicas e Cirúrgicas (HABM) – 720h Conteúdos: Disciplinas/Conteúdos: Simulações Clínicas e Cirúrgicas / Realidade Virtual e Aumentada / Robótica e IA / TICS (do 1º ao 8º período): Introdução a Semiologia (1º) / Saúde da Criança e do adolescente (2º) / Saúde da Mulher (3º) / Saúde do Adulto e Idoso (4º) / Simulação cirúrgica (5º) / Exames clínicos e laboratoriais (6) / Simulação em redes de atenção (7) / Tecnologias em saúde (8º).  Eixos: Educação em Saúde, Atenção à Saúde e Gestão dos Sistemas de Saúde Módulo: Práticas de Integração Ensino-Serviços de Saúde-Comunidade (PRIESC) - 735 h, sendo: Prática Integradora de Extensão de I a VIII, cada uma com 45h, totalizando 360h e Atividades de Extensão com 375h Conteúdos: Atenção à Saúde / Educação em Saúde / Gestão dos Sistemas de Saúde (do 1º ao 8º período)'
text = 'Lorem ipsum dolor sit amet, consectetur adipiscing elit. Quisque feugiat dignissim ligula sed feugiat.\n'
# text2 = 'Fusce congue tincidunt risus, et maximus elit egestas non. In quis massa dapibus, bibendum magna sed, pellentesque risus.'
# text3 = 'Quisque a tincidunt urna, quis pulvinar felis. Praesent est lacus, malesuada nec quam at, tincidunt laoreet felis. Sed.'
wordcloud = WordCloud(background_color="white", max_words=20, mode='RGBA',color_func=lambda *args, **kwargs: "black").generate(text)
# topic.wordcloud = WordCloud(mode='RGBA', background_color='white', max_words=20, color_func=lambda *args, **kwargs: "black").generate_from_frequencies(tfidf_data_frame.T.sum(axis=1))
fig = plt.figure(1, figsize=(10, 8))
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')
fig.patch.set_visible(False)
plt.imshow(wordcloud)
plt.savefig('wc1.jpg')

# %%
# wordcloud2 = WordCloud(background_color="white", max_words=50).generate(text2)
wordcloud2 = WordCloud(background_color="white", max_words=20, mode='RGBA',color_func=lambda *args, **kwargs: "black").generate(text2)
fig = plt.figure(1, figsize=(10, 8))
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')
plt.imshow(wordcloud2)
plt.savefig('wc2.jpg')

# %%
wordcloud3 = WordCloud(background_color="white", max_words=20, mode='RGBA',color_func=lambda *args, **kwargs: "black").generate(text3)
fig = plt.figure(1, figsize=(10, 8))
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')
plt.imshow(wordcloud3)
plt.savefig('wc3.jpg')
